# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
xls = pd.ExcelFile("visadata.xls", header = None)

# %%
df1 = pd.read_excel(xls, 'FY07', header = None)
df1.head()
# Out:
#                  0    1    2    3     4      5     6          7          8   \
# 0  Fiscal Year 2007  A-1  A-2  A-3   B-1  B-1,2   B-2  B-1,2/BCC  B-1,2/BCV
# 1            Africa  NaN  NaN  NaN   NaN    NaN   NaN        NaN        NaN
# 2           Algeria   26  220    1  1228    915  1747          0          0
# 3            Angola   82  155    3   665   1586   283          0          0
# 4             Benin   25  145    0    17    920    22          0          0
#
#     9      ...        80   81   82   83   84   85   86           87   88  \
# 0  C-1     ...       U-1  U-2  U-3  U-4  V-1  V-2  V-3  Total Visas  BCC
# 1  NaN     ...       NaN  NaN  NaN  NaN  NaN  NaN  NaN          NaN  NaN
# 2   22     ...         0    0    0    0    0    0    0         4855    0
# 3   12     ...         0    0    0    0    0    0    0         3754    0
# 4    5     ...         0    0    0    0    0    0    0         1582    0
#
#             89
# 0  Grand Total
# 1          NaN
# 2         4855
# ...

# %%
#df1['country_name'] = df1['Fiscal Year 2007'].fillna(df1['Fiscal Year 2007'])

# %%
df1.rename(columns={20: 'F1'}, inplace=True)
df1.rename(columns={0: 'country'}, inplace=True)

# %%
df1.country
# Out:
# 0                              Fiscal Year 2007
# 1                                        Africa
# 2                                       Algeria
# 3                                        Angola
# 4                                         Benin
# 5                                      Botswana
# 6                                  Burkina Faso
# 7                                       Burundi
# 8                                      Cameroon
# 9                                    Cape Verde
# 10                     Central African Republic
# 11                                         Chad
# 12                                      Comoros
# 13     Congo, Dem. Rep. of the (Congo Kinshasa)
# 14       Congo, Rep. of the (Congo Brazzaville)
# 15                                Cote d'Ivoire
# 16                                     Djibouti
# 17                                        Egypt
# 18                            Equatorial Guinea
# 19                                      Eritrea
# ...

# %%
array = ['China - mainland', 'China - Taiwan','Hong Kong S.A.R.', 'Grand Totals']
df1_china = df1.loc[df1['country'].isin(array)]
df1_china.dtypes
# Out:
# country    object
# 1          object
# 2          object
# 3          object
# 4          object
# 5          object
# 6          object
# 7          object
# 8          object
# 9          object
# 10         object
# 11         object
# 12         object
# 13         object
# 14         object
# 15         object
# 16         object
# 17         object
# 18         object
# 19         object
# F1         object
# 21         object
# 22         object
# 23         object
# 24         object
# 25         object
# 26         object
# 27         object
# 28         object
# 29         object
#             ...
# 60         object
# 61         object
# 62         object
# 63         object
# 64         object
# 65         object
# 66         object
# 67         object
# 68         object
# 69         object
# 70         object
# 71         object
# 72         object
# 73         object
# 74         object
# 75         object
# 76         object
# 77         object
# 78         object
# ...

# %%
df1_china = df1_china[['country', 'F1']]
df1_china['year'] = ('2007')
df1_china
# Out:
#               country      F1  year
# 66   China - mainland   39535  2007
# 67     China - Taiwan   14973  2007
# 68   Hong Kong S.A.R.    2325  2007
# 225      Grand Totals  298393  2007

# %%
df2 = pd.read_excel(xls, 'FY08', header=None)
df2.rename(columns={20: 'F1'}, inplace=True)
df2.rename(columns={0: 'country'}, inplace=True)
df2_china = df2.loc[df2['country'].isin(array)]
df2_china = df2_china[['country', 'F1']]
df2_china['year'] = ('2008')
df2_china
# Out:
#               country      F1  year
# 66   China - mainland   56258  2008
# 67     China - Taiwan   14640  2008
# 68   Hong Kong S.A.R.    2401  2008
# 228      Grand Totals  340711  2008

# %%
df3 = pd.read_excel(xls, 'FY09', header=None)
df3.rename(columns={20: 'F1'}, inplace=True)
df3.rename(columns={0: 'country'}, inplace=True)
df3_china = df3.loc[df3['country'].isin(array)]
df3_china = df3_china[['country', 'F1']]
df3_china['year'] = ('2009')
df3_china
# Out:
#               country      F1  year
# 66   China - mainland   81842  2009
# 67     China - Taiwan   10978  2009
# 68   Hong Kong S.A.R.    2221  2009
# 228      Grand Totals  331208  2009

# %%
df4 = pd.read_excel(xls, 'FY10', header=None)
df4.rename(columns={20: 'F1'}, inplace=True)
df4.rename(columns={0: 'country'}, inplace=True)
df4_china = df4.loc[df4['country'].isin(array)]
df4_china = df4_china[['country', 'F1']]
df4_china['year'] = ('2010')
df4_china
# Out:
#               country      F1  year
# 66   China - mainland  113772  2010
# 67     China - Taiwan   10785  2010
# 68   Hong Kong S.A.R.    2631  2010
# 228      Grand Totals  385210  2010

# %%
df5 = pd.read_excel(xls, 'FY11', header=None)
df5.rename(columns={21: 'F1'}, inplace=True)
df5.rename(columns={0: 'country'}, inplace=True)
df5_china = df5.loc[df5['country'].isin(array)]
df5_china = df5_china[['country', 'F1']]
df5_china['year'] = ('2011')
df5_china
# Out:
#               country      F1  year
# 67   China - mainland  153026  2011
# 68     China - Taiwan   11200  2011
# 69   Hong Kong S.A.R.    2681  2011
# 229      Grand Totals  447410  2011

# %%
df6 = pd.read_excel(xls, 'FY12', header=None)
df6.rename(columns={23: 'F1'}, inplace=True)
df6.rename(columns={0: 'country'}, inplace=True)
df6_china = df6.loc[df6['country'].isin(array)]
df6_china = df6_china[['country', 'F1']]
df6_china['year'] = ('2012')
df6_china
# Out:
#               country      F1  year
# 67   China - mainland  189402  2012
# 68     China - Taiwan   10621  2012
# 69   Hong Kong S.A.R.    2785  2012
# 229      Grand Totals  486900  2012

# %%
df7 = pd.read_excel(xls, 'FY13', header=None)
df7.rename(columns={23: 'F1'}, inplace=True)
df7.rename(columns={0: 'country'}, inplace=True)
df7_china = df7.loc[df7['country'].isin(array)]
df7_china = df7_china[['country', 'F1']]
df7_china['year'] = ('2013')
df7_china
# Out:
#               country      F1  year
# 67   China - mainland  217593  2013
# 68     China - Taiwan    9921  2013
# 69   Hong Kong S.A.R.    2947  2013
# 228      Grand Totals  534320  2013

# %%
df8 = pd.read_excel(xls, 'FY14', header=None)
df8.rename(columns={22: 'F1'}, inplace=True)
df8.rename(columns={0: 'country'}, inplace=True)
df8_china = df8.loc[df8['country'].isin(array)]
df8_china = df8_china[['country', 'F1']]
df8_china['year'] = ('2014')
df8_china
# Out:
#               country      F1  year
# 67   China - mainland  244927  2014
# 68     China - Taiwan    9731  2014
# 69   Hong Kong S.A.R.    2871  2014
# 228      Grand Totals  595569  2014

# %%
df9 = pd.read_excel(xls, 'FY15', header=None)
df9.rename(columns={22: 'F1'}, inplace=True)
df9.rename(columns={0: 'country'}, inplace=True)
df9_china = df9.loc[df9['country'].isin(array)]
df9_china = df9_china[['country', 'F1']]
df9_china['year'] = ('2015')
df9_china
# Out:
#               country      F1  year
# 67   China - mainland  274460  2015
# 68     China - Taiwan    9791  2015
# 69   Hong Kong S.A.R.    3060  2015
# 228      Grand Totals  644233  2015

# %%
df10 = pd.read_excel(xls, 'FY16', header=None)
df10.rename(columns={22: 'F1'}, inplace=True)
df10.rename(columns={0: 'country'}, inplace=True)
df10_china = df10.loc[df10['country'].isin(array)]
df10_china = df10_china[['country', 'F1']]
df10_china['year'] = ('2016')
df10_china
# Out:
#               country      F1  year
# 67   China - mainland  148016  2016
# 68     China - Taiwan    9730  2016
# 69   Hong Kong S.A.R.    2746  2016
# 228      Grand Totals  471728  2016

# %%
df11 = pd.read_excel(xls, 'FY17', header=None)
df11.rename(columns={22: 'F1'}, inplace=True)
df11.rename(columns={0: 'country'}, inplace=True)
df11_china = df11.loc[df11['country'].isin(array)]
df11_china = df11_china[['country', 'F1']]
df11_china['year'] = ('2017')
df11_china
# Out:
#               country      F1  year
# 67   China - mainland  112817  2017
# 68     China - Taiwan    9117  2017
# 69   Hong Kong S.A.R.    2694  2017
# 228      Grand Totals  393573  2017

# %%
frames = [df1_china, df2_china, df3_china, df4_china, df5_china, df6_china, df7_china, df8_china, df9_china, df10_china, df11_china]

df_china = pd.concat(frames)
df_china[['year', 'country', 'F1']]
# Out:
#      year           country      F1
# 66   2007  China - mainland   39535
# 67   2007    China - Taiwan   14973
# 68   2007  Hong Kong S.A.R.    2325
# 225  2007      Grand Totals  298393
# 66   2008  China - mainland   56258
# 67   2008    China - Taiwan   14640
# 68   2008  Hong Kong S.A.R.    2401
# 228  2008      Grand Totals  340711
# 66   2009  China - mainland   81842
# 67   2009    China - Taiwan   10978
# 68   2009  Hong Kong S.A.R.    2221
# 228  2009      Grand Totals  331208
# 66   2010  China - mainland  113772
# 67   2010    China - Taiwan   10785
# 68   2010  Hong Kong S.A.R.    2631
# 228  2010      Grand Totals  385210
# 67   2011  China - mainland  153026
# 68   2011    China - Taiwan   11200
# 69   2011  Hong Kong S.A.R.    2681
# 229  2011      Grand Totals  447410
# 67   2012  China - mainland  189402
# 68   2012    China - Taiwan   10621
# 69   2012  Hong Kong S.A.R.    2785
# 229  2012      Grand Totals  486900
# 67   2013  China - mainland  217593
# ...

# %%
df_total = df_china[df_china['country'] == "Grand Totals"]
df_total
# Out:
#           country      F1  year
# 225  Grand Totals  298393  2007
# 228  Grand Totals  340711  2008
# 228  Grand Totals  331208  2009
# 228  Grand Totals  385210  2010
# 229  Grand Totals  447410  2011
# 229  Grand Totals  486900  2012
# 228  Grand Totals  534320  2013
# 228  Grand Totals  595569  2014
# 228  Grand Totals  644233  2015
# 228  Grand Totals  471728  2016
# 228  Grand Totals  393573  2017

# %%
df_chinavisa = df_china[df_china['country'].isin(["China - mainland", "China - Taiwan", "Hong Kong S.A.R."])]
df_chinavisa
# Out:
#              country      F1  year
# 66  China - mainland   39535  2007
# 67    China - Taiwan   14973  2007
# 68  Hong Kong S.A.R.    2325  2007
# 66  China - mainland   56258  2008
# 67    China - Taiwan   14640  2008
# 68  Hong Kong S.A.R.    2401  2008
# 66  China - mainland   81842  2009
# 67    China - Taiwan   10978  2009
# 68  Hong Kong S.A.R.    2221  2009
# 66  China - mainland  113772  2010
# 67    China - Taiwan   10785  2010
# 68  Hong Kong S.A.R.    2631  2010
# 67  China - mainland  153026  2011
# 68    China - Taiwan   11200  2011
# 69  Hong Kong S.A.R.    2681  2011
# 67  China - mainland  189402  2012
# 68    China - Taiwan   10621  2012
# 69  Hong Kong S.A.R.    2785  2012
# 67  China - mainland  217593  2013
# 68    China - Taiwan    9921  2013
# 69  Hong Kong S.A.R.    2947  2013
# 67  China - mainland  244927  2014
# 68    China - Taiwan    9731  2014
# 69  Hong Kong S.A.R.    2871  2014
# 67  China - mainland  274460  2015
# 68    China - Taiwan    9791  2015
# ...

# %%
df_chinaf1 = df_chinavisa.groupby('year').F1.sum().reset_index(name="F1 Visa issued to Chinese")
df_chinaf1
# Out:
#     year  F1 Visa issued to Chinese
# 0   2007                      56833
# 1   2008                      73299
# 2   2009                      95041
# 3   2010                     127188
# 4   2011                     166907
# 5   2012                     202808
# 6   2013                     230461
# 7   2014                     257529
# 8   2015                     287311
# 9   2016                     160492
# 10  2017                     124628

# %%
##final dataframe
df_info = pd.merge(df_chinaf1, df_total, on=['year'])
df_info = df_info.drop(columns=['country'])
df_info['year'] = df_info.year.astype(int)
df_info
# Out:
#     year  F1 Visa issued to Chinese      F1
# 0   2007                      56833  298393
# 1   2008                      73299  340711
# 2   2009                      95041  331208
# 3   2010                     127188  385210
# 4   2011                     166907  447410
# 5   2012                     202808  486900
# 6   2013                     230461  534320
# 7   2014                     257529  595569
# 8   2015                     287311  644233
# 9   2016                     160492  471728
# 10  2017                     124628  393573

# %%
df_info['pct_f1'] =  df_info['F1 Visa issued to Chinese'] / df_info['F1'] * 100
df_info
# Out:
#     year  F1 Visa issued to Chinese      F1   pct_f1
# 0   2007                      56833  298393  19.0464
# 1   2008                      73299  340711  21.5135
# 2   2009                      95041  331208  28.6953
# 3   2010                     127188  385210  33.0178
# 4   2011                     166907  447410  37.3052
# 5   2012                     202808  486900  41.6529
# 6   2013                     230461  534320  43.1316
# 7   2014                     257529  595569  43.2408
# 8   2015                     287311  644233  44.5974
# 9   2016                     160492  471728  34.0221
# 10  2017                     124628  393573  31.6658

# %%
df_info.to_csv("usvisa.csv", index=False)

# %%
#ax = df_info.plot(x='year', y='F1 Visa issued to Chinese',kind='bar')

# %%
plt.rcdefaults()

# %%
#plt.style.use('fivethirtyeight')
ax = df_info.plot(x='year', y='F1 Visa issued to Chinese',figsize=(10,6), legend=False, color='purple', alpha=0.7, style='.-',linewidth='3', markersize= '15')
ax.set_title("Numbers of US issued F-1 student visas to Chinese drop dramatically after 2015", fontname='Microsoft Sans Serif', fontsize=24, weight='bold', pad=30, loc='center')
ax.title.set_fontsize(18)
ax.set_xticks([2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017])
ax.title.set_fontname('Microsoft Sans Serif')
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(which='major', left=False, bottom=False, top=False, grid_alpha=0.5)
ax.grid(True, axis='x')
ax.grid(True, axis='y')
ax.set_axisbelow(True)
ax.set_ylim(0,300000)
ax.xaxis.label.set_visible(False)
ax.tick_params(which='major', left=False, bottom=False, top=False, grid_alpha=0.3)
#plt.title("Numbers of US issued F-1 student visas to Chinese drop dramatically after 2015", loc='left', fontsize=20, fontweight=30, color='Black', pad=40)
plt.xlabel("Year")
plt.ylabel("Number of F-1 visas", labelpad=30, fontsize=15)
from matplotlib.ticker import FuncFormatter
def with_commas(value, pos):
    return "{:,}".format(int(value))
formatter = FuncFormatter(with_commas)

ax.yaxis.set_major_formatter(formatter)
plt.tight_layout()
plt.savefig('output1.pdf')
plt.show()

# %%
#plt.style.use('fivethirtyeight')
ax2 = df_info.plot(kind='bar',x='year', y=['F1 Visa issued to Chinese','F1'], stacked=True, figsize=(10,6), color = ["#800080", "#B23CB2"], label = ["F1 Visa issued to Chinese",'F1 Visa issued in total'])
ax2.set_title("Numbers of US issued F-1 student visas to Chinese VS in Total",  fontname='Microsoft Sans Serif', fontsize=22, weight='bold', pad=30)
ax2.spines['top'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.grid(True, axis='y')
ax2.tick_params(which='major', left=False, bottom=False, top=False, grid_alpha=0.3)
ax2.yaxis.label.set_visible(False)


ax2.legend(ncol=2, 
           loc=9, #‘upper center’
           bbox_to_anchor=(0.35, 0.9),
           frameon=False,
           columnspacing=3,
           labelspacing=1,
           bbox_transform=plt.gcf().transFigure)

ax2.xaxis.label.set_visible(False)
plt.tight_layout()
plt.ylabel("Number of F-1 visas", labelpad=30, fontsize=15)
plt.xticks(rotation=20)
plt.savefig('output2.pdf')


from matplotlib.ticker import FuncFormatter
def with_commas(value, pos):
    return "{:,}".format(int(value))
formatter = FuncFormatter(with_commas)

ax2.yaxis.set_major_formatter(formatter)

plt.xticks(rotation=20)
plt.savefig('output2.pdf')
plt.show()

# %%
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42
})


ax3 = df_info.plot(x='year', y='pct_f1', figsize=(12,6), color='purple', alpha=0.7, style='.-',linewidth='3', markersize= '15')
ax3.set_xticks([2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017])
ax3.set_title("The percentage of the US issued student visa to Chinese droped over past two years",  fontname='Microsoft Sans Serif', fontsize=22, weight='bold', pad=40)
ax3.set_ylim(0,60)
ax3.legend_.remove()
ax3.spines['top'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.tick_params(which='major', left=False, bottom=False, top=False, grid_alpha=0.5)
ax3.grid(True, axis='x')
ax3.grid(True, axis='y')

ax3.xaxis.label.set_visible(False)
ax3.yaxis.label.set_visible(False)

import matplotlib.ticker as mtick
ax3.yaxis.set_major_formatter(mtick.PercentFormatter())

plt.tight_layout()
plt.savefig('output3.pdf')
plt.show()

# %%
#download a csv online
df_number =pd.read_csv("international students in the US.csv")
df_number
# Out:
#    year    FM
# 0  2018  1.20
# 1  2017  1.21
# 2  2016  1.18
# 3  2015  1.11
# 4  2014  1.02
# 5  2013  0.91
# 6  2012  0.86
# 7  2011  0.82
# 8  2010  0.76

# %%
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42
})

ax4 = df_number.plot(x='year', y='FM', figsize=(10,6), color='purple', alpha=0.7, style='.-',linewidth='3', markersize= '15')
ax4.legend(['International students in the US(millions)'])
ax4.set_title("Less international students in the US", pad=30)
ax4.set_ylim([0,1.4])
ax4.legend_.remove()
ax4.spines['top'].set_visible(False)
ax4.spines['left'].set_visible(False)
ax4.spines['bottom'].set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.title.set_fontsize(23)
ax4.xaxis.label.set_visible(False)

ax4.grid(True, axis='x')
ax4.grid(True, axis='y')
ax4.tick_params(which='major', left=False, bottom=False, top=False, grid_alpha=0.5)
plt.xlabel("")
plt.ylabel("Numbers in millions", labelpad=30, fontsize=15)

plt.tight_layout()
plt.savefig('output4.pdf')
plt.show()
