# %%
import pandas as pd
import glob

# %%
filenames = glob.glob("year*.xls")
filenames
# Out:
# ['year2014.xls',
#  'year2006.xls',
#  'year2012.xls',
#  'year2013.xls',
#  'year2007.xls',
#  'year2005.xls',
#  'year2004.xls',
#  'year2010.xls',
#  'year2009.xls',
#  'year2008.xls']

# %%
dataframe = []
for filename in filenames:
    df = pd.read_excel(filename)
    df['filename'] = filename  
    df['year'] = df['filename'].str.extract(r"(\d\d\d\d).xls")
    dataframe.append(df)

years = pd.concat(dataframe, ignore_index=True, sort=True)
years.head()
# Out:
#    1st Births  1st Births.1  2nd Births  2nd Births.1  3rd Births and over  \
# 0      7092.0         22.96      3431.0         11.11                490.0
# 1         NaN           NaN         NaN           NaN                  NaN
# 2       244.0          7.32        17.0          0.50                  1.0
# 3         2.0          0.34         NaN          0.03                  NaN
# 4        13.0          1.95         1.0          0.08                  NaN
#
#    3rd Births and over.1    Age  \
# 0                   1.59  Total
# 1                    NaN    NaN
# 2                   0.02  15-19
# 3                    NaN     15
# 4                    NaN     16
#
#    Average Number   of  Childbearing  Woman (person)  Births(person)  \
# 0                                           308867.0         11022.0
# 1                                                NaN             NaN
# 2                                            33282.0           261.0
# 3                                             6088.0             2.0
# 4                                             6784.0            14.0
#
#    Fertility Rate (‰)      filename  year
# 0               35.68  year2014.xls  2014
# 1                 NaN  year2014.xls  2014
# 2                7.84  year2014.xls  2014
# 3                0.38  year2014.xls  2014
# 4                2.03  year2014.xls  2014

# %%
# years.dropna(subset=['Age'], inplace=True)
# years.head()

# %%
years = years.rename(columns={"1st Births.1": "1st Births.rate", "2nd Births.1": "2nd Births.rate", "3rd Births and over.1": "3rd Births and over.rate"})

# %%
years = years.sort_values(by='year', ascending = True)
years.head()
# Out:
#      1st Births  1st Births.rate  2nd Births  2nd Births.rate  \
# 326       128.0             9.81       314.0            24.13
# 320       706.0            72.28       270.0            27.66
# 319       824.0            93.17       224.0            25.30
# 318      1030.0           121.19       175.0            20.54
# 317      3440.0            70.86      1344.0            27.68
#
#      3rd Births and over  3rd Births and over.rate    Age  \
# 326                 43.0                      3.31     32
# 320                 42.0                      4.35     27
# 319                 34.0                      3.90     26
# 318                 29.0                      3.45     25
# 317                190.0                      3.91  25-29
#
#      Average Number   of  Childbearing  Woman (person)  Births(person)  \
# 326                                            13015.0           485.0
# 320                                             9763.0          1018.0
# 319                                             8846.0          1082.0
# 318                                             8496.0          1234.0
# 317                                            48555.0          4974.0
#
#      Fertility Rate (‰)      filename  year
# 326               37.25  year2004.xls  2004
# 320              104.29  year2004.xls  2004
# 319              122.37  year2004.xls  2004
# 318              145.19  year2004.xls  2004
# 317              102.44  year2004.xls  2004

# %%
years = years.drop(columns=['filename'])
years.head()
# Out:
#      1st Births  1st Births.rate  2nd Births  2nd Births.rate  \
# 326       128.0             9.81       314.0            24.13
# 320       706.0            72.28       270.0            27.66
# 319       824.0            93.17       224.0            25.30
# 318      1030.0           121.19       175.0            20.54
# 317      3440.0            70.86      1344.0            27.68
#
#      3rd Births and over  3rd Births and over.rate    Age  \
# 326                 43.0                      3.31     32
# 320                 42.0                      4.35     27
# 319                 34.0                      3.90     26
# 318                 29.0                      3.45     25
# 317                190.0                      3.91  25-29
#
#      Average Number   of  Childbearing  Woman (person)  Births(person)  \
# 326                                            13015.0           485.0
# 320                                             9763.0          1018.0
# 319                                             8846.0          1082.0
# 318                                             8496.0          1234.0
# 317                                            48555.0          4974.0
#
#      Fertility Rate (‰)  year
# 326               37.25  2004
# 320              104.29  2004
# 319              122.37  2004
# 318              145.19  2004
# 317              102.44  2004

# %%
years_small = years[['Age', 'Fertility Rate (‰)', '1st Births.rate', '2nd Births.rate', '3rd Births and over.rate', 'year']]

# %%
years_small
# Out:
#         Age  Fertility Rate (‰)  1st Births.rate  2nd Births.rate  \
# 326      32               37.25             9.81            24.13
# 320      27              104.29            72.28            27.66
# 319      26              122.37            93.17            25.30
# 318      25              145.19           121.19            20.54
# 317   25-29              102.44            70.86            27.68
# 316      24              157.39           137.86            16.04
# 315      23              153.35           137.67            12.82
# 314      22              138.40           128.89             7.99
# 313      21              102.05            96.58             4.59
# 321      28               84.42            49.18            31.43
# 312      20               56.42            53.13             2.77
# 310      19               20.84            19.72             0.87
# 309      18                7.27             7.07             0.10
# 308      17                2.40             2.28             0.12
# 346      49                0.47             0.20             0.14
# 307      16                0.85             0.75             0.09
# 306      15                0.51             0.51              NaN
# 305   15-19                5.25             4.99             0.20
# 304   Total               38.01            26.12            10.10
# 311   20-24              122.67           111.73             9.04
# 322      29               69.04            33.53            31.56
# 323   30-34               38.28            11.82            22.78
# 335   40-44                1.77             0.28             1.00
# 344      47                0.69             0.08             0.40
# 343      46                0.68             0.14             0.30
# 342      45                0.52             0.11             0.17
# 341   45-49                0.56             0.12             0.23
# 340      44                0.74             0.20             0.32
# 339      43                0.90             0.18             0.30
# 338      42                1.37             0.28             0.47
# ..      ...                 ...              ...              ...
# 1       NaN                 NaN              NaN              NaN
# 23    30-34               50.84            22.84            24.15
# 11       21               53.75            47.08             6.55
# 24       30               61.50            32.45            25.05
# 49       49                1.37             1.05             0.19
# 26       32               49.84            20.60            25.41
# 48       48                0.96             0.63             0.12
# 47       47                1.75             0.53             1.06
# 46       46                1.89             0.56             0.83
# 45       45                2.89             1.21             0.90
# 44    45-49                1.76             0.80             0.61
# 43      NaN                 NaN              NaN              NaN
# 42       44                2.52             0.86             1.38
# 41       43                4.25             1.06             2.19
# 40       42                3.86             1.21             2.14
# 39       41                5.19             1.97             2.54
# 25       31               61.94            27.89            30.69
# 38       40                7.81             2.61             3.64
# 36      NaN                 NaN              NaN              NaN
# 35       39               12.53             3.68             6.85
# 34       38               14.12             4.13             7.42
# 33       37               16.87             5.23             9.70
# 32       36               23.00             7.43            11.52
# 31       35               29.60            10.35            15.64
# 30    35-39               18.68             5.96             9.95
# 29      NaN                 NaN              NaN              NaN
# 28       34               34.33            14.67            16.83
# 27       33               45.30            17.79            22.30
# 37    40-44                4.66             1.52             2.35
# 0     Total               35.68            22.96            11.11
#
#      3rd Births and over.rate  year
# 326                      3.31  2004
# 320                      4.35  2004
# 319                      3.90  2004
# 318                      3.45  2004
# 317                      3.91  2004
# 316                      3.49  2004
# 315                      2.87  2004
# 314                      1.51  2004
# 313                      0.89  2004
# 321                      3.81  2004
# 312                      0.51  2004
# 310                      0.25  2004
# 309                      0.10  2004
# 308                       NaN  2004
# 346                      0.13  2004
# 307                       NaN  2004
# 306                       NaN  2004
# 305                      0.06  2004
# 304                      1.79  2004
# 311                      1.90  2004
# 322                      3.96  2004
# 323                      3.68  2004
# 335                      0.49  2004
# 344                      0.21  2004
# 343                      0.24  2004
# 342                      0.24  2004
# 341                      0.21  2004
# 340                      0.21  2004
# 339                      0.42  2004
# 338                      0.63  2004
# ..                        ...   ...
# 1                         NaN  2014
# 23                       3.76  2014
# 11                       0.12  2014
# 24                       4.00  2014
# 49                       0.13  2014
# 26                       3.83  2014
# 48                       0.21  2014
# 47                       0.16  2014
# 46                       0.50  2014
# 45                       0.78  2014
# 44                       0.35  2014
# 43                        NaN  2014
# 42                       0.28  2014
# 41                       1.01  2014
# 40                       0.52  2014
# 39                       0.60  2014
# 25                       3.36  2014
# 38                       1.57  2014
# 36                        NaN  2014
# 35                       1.86  2014
# 34                       2.57  2014
# 33                       1.84  2014
# 32                       4.05  2014
# 31                       3.36  2014
# 30                       2.68  2014
# 29                        NaN  2014
# 28                       2.59  2014
# 27                       4.99  2014
# 37                       0.78  2014
# 0                        1.59  2014
#
# [499 rows x 6 columns]

# %%
years_small[years_small['Age'] == ' Total']
# Out:
#         Age  Fertility Rate (‰)  1st Births.rate  2nd Births.rate  \
# 304   Total               38.01            26.12            10.10
# 204   Total               34.99            23.02            10.62
#
#      3rd Births and over.rate  year
# 304                      1.79  2004
# 204                      1.36  2007

# %%
years_total = years_small[years_small['Age'].str.contains('Total', na=False)]
years_total
# Out:
#            Age  Fertility Rate (‰)  1st Births.rate  2nd Births.rate  \
# 304      Total               38.01            26.12            10.10
# 255      Total               38.29            26.53            10.44
# 51       Total               34.44            21.68            10.90
# 204      Total               34.99            23.02            10.62
# 448      Total               37.46            25.04            11.05
# 397      Total               38.83            26.22            11.18
# 347  总计  Total               36.14            24.24            10.60
# 102      Total               29.75            19.75             8.72
# 153      Total               35.89            23.38            10.92
# 0        Total               35.68            22.96            11.11
#
#      3rd Births and over.rate  year
# 304                      1.79  2004
# 255                      1.32  2005
# 51                       1.85  2006
# 204                      1.36  2007
# 448                      1.37  2008
# 397                      1.43  2009
# 347                      1.30  2010
# 102                      1.29  2012
# 153                      1.58  2013
# 0                        1.59  2014

# %%
filenames2 = glob.glob("year*.csv")
filenames2
# Out:
# ['year2015.csv', 'year2016.csv']

# %%
dataframe2 = []
for filename2 in filenames2:
    df2 = pd.read_csv(filename2,encoding = "ISO-8859-1")
    df2['filename2'] = filename2  
    df2['year'] = df2['filename2'].str.extract(r"(\d\d\d\d).csv")
    dataframe2.append(df2)

years2 = pd.concat(dataframe2, ignore_index=True, sort=True)
years2.head()
# Out:
#    1st Births 1st Births.1  2nd Births  2nd Births.1  3rd Births and over  \
# 0      6553.0         21.5      4082.0         13.40                735.0
# 1       318.0        10.06        28.0          0.89                  7.0
# 2         5.0         0.87         NaN           NaN                  NaN
# 3        18.0         2.83         NaN           NaN                  NaN
# 4        52.0         8.59         3.0          0.50                  NaN
#
#    3rd Births and over.1     Age  \
# 0                   2.41   Total
# 1                    NaN   15-19
# 2                    NaN      15
# 3                    NaN      16
# 4                    NaN      17
#
#    Average Number   of  Childbearing  Woman (person)  Births(person)  \
# 0                                             304733           11377
# 1                                              31623             354
# 2                                               5732               5
# 3                                               6091              16
# 4                                               6055              55
#
#    Fertility Rate (¡ë)  Unnamed: 10  Unnamed: 11  Unnamed: 12     filename2  \
# 0                37.33          NaN          NaN          NaN  year2015.csv
# 1                11.19          NaN          NaN          NaN  year2015.csv
# 2                 0.87          NaN          NaN          NaN  year2015.csv
# 3                 2.63          NaN          NaN          NaN  year2015.csv
# 4                 9.08          NaN          NaN          NaN  year2015.csv
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %%
# years2.dropna(subset=['Age'], inplace=True)
# years2.head()

# %%
years2 = years2.rename(columns={"1st Births.1": "1st Births.rate", "2nd Births.1": "2nd Births.rate", "3rd Births and over.1": "3rd Births and over.rate", "Fertility Rate (¡ë)" : "Fertility Rate (‰)"})

# %%
years2.head()
# Out:
#    1st Births 1st Births.rate  2nd Births  2nd Births.rate  \
# 0      6553.0            21.5      4082.0            13.40
# 1       318.0           10.06        28.0             0.89
# 2         5.0            0.87         NaN              NaN
# 3        18.0            2.83         NaN              NaN
# 4        52.0            8.59         3.0             0.50
#
#    3rd Births and over  3rd Births and over.rate     Age  \
# 0                735.0                      2.41   Total
# 1                  7.0                       NaN   15-19
# 2                  NaN                       NaN      15
# 3                  NaN                       NaN      16
# 4                  NaN                       NaN      17
#
#    Average Number   of  Childbearing  Woman (person)  Births(person)  \
# 0                                             304733           11377
# 1                                              31623             354
# 2                                               5732               5
# 3                                               6091              16
# 4                                               6055              55
#
#    Fertility Rate (‰)  Unnamed: 10  Unnamed: 11  Unnamed: 12     filename2  \
# 0               37.33          NaN          NaN          NaN  year2015.csv
# 1               11.19          NaN          NaN          NaN  year2015.csv
# 2                0.87          NaN          NaN          NaN  year2015.csv
# 3                2.63          NaN          NaN          NaN  year2015.csv
# 4                9.08          NaN          NaN          NaN  year2015.csv
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %%
years2_small = years2[['Age', 'Fertility Rate (‰)', '1st Births.rate', '2nd Births.rate', '3rd Births and over.rate', 'year']]

# %%
years2_small
# Out:
#        Age  Fertility Rate (‰) 1st Births.rate  2nd Births.rate  \
# 0    Total               37.33            21.5        13.400000
# 1    15-19               11.19           10.06         0.890000
# 2       15                0.87            0.87              NaN
# 3       16                2.63            2.83              NaN
# 4       17                9.08            8.59         0.500000
# 5       18               15.52           13.52         1.540000
# 6       19               24.59           21.83         2.070000
# 7    20-24               79.77           60.46        17.960000
# 8       20               46.55           42.17         4.380000
# 9       21               65.17           54.29        10.010000
# 10      22               75.55           80.04        14.510000
# 11      23              100.21            72.6        25.620000
# 12      24               97.67           66.76        28.440000
# 13   25-29               93.62           54.13        34.770000
# 14      25              105.73           68.71        33.770000
# 15      26              103.52            63.6        34.920000
# 16      27               89.92           53.01        31.810000
# 17      28               84.02           41.68        35.900000
# 18      29               80.83           38.71        38.220000
# 19   30-34               49.03           17.01        25.740000
# 20      30               67.85           27.77        33.230000
# 21      31               54.38           20.63        26.950000
# 22      32               48.77           15.97        24.920000
# 23      33               40.86           11.14        23.220000
# 24      34               34.99            9.34        20.290000
# 25   35-39               17.04             4.3         9.710000
# 26      35               29.74            8.16        16.570000
# 27      36               18.93               5        11.090000
# 28      37               17.22            4.18        10.130000
# 29      38               11.66            2.83         5.770000
# ..     ...                 ...             ...              ...
# 56   25-29               74.31           41.55        28.800000
# 57      25               77.51           49.26        25.210000
# 58      26               78.87           47.04        28.250000
# 59      27               74.31           42.34        29.760000
# 60      28               71.77            36.8        30.570000
# 61      29               65.80           30.11        30.730000
# 62   30-34               45.31           14.98        25.420000
# 63      30               57.60           22.69        29.610000
# 64      31               51.25           17.88        28.220000
# 65      32               44.63           14.24        25.560000
# 66      33               39.20           11.29        23.210000
# 67      34               33.62            8.69        20.360000
# 68   35-39               18.60            4.63        10.960000
# 69      35               27.93            6.91        16.990000
# 70      36               23.10             5.5        14.030000
# 71      37               18.02            4.43        10.640000
# 72      38               13.68            3.55         7.690000
# 73      39               10.88            2.88         5.850000
# 74   40-44                5.37            1.85         2.450000
# 75      40                8.29            2.45         4.200000
# 76      41                6.26            2.03         2.950000
# 77      42                5.06            1.85         2.194315
# 78      43                4.13             1.6         1.750000
# 79      44                3.58            1.41         1.450000
# 80   45-49                3.11            1.25         1.230000
# 81      45                3.31            1.36         1.280000
# 82      46                3.02            1.25         1.220000
# 83      47                3.06            1.27         1.160000
# 84      48                3.06            1.21         1.210000
# 85      49                3.08            1.17         1.280000
#
#     3rd Births and over.rate  year
# 0                       2.41  2015
# 1                        NaN  2015
# 2                        NaN  2015
# 3                        NaN  2015
# 4                        NaN  2015
# 5                       0.31  2015
# 6                       0.69  2015
# 7                       1.33  2015
# 8                       0.13  2015
# 9                       0.75  2015
# 10                      0.87  2015
# 11                      1.89  2015
# 12                      2.38  2015
# 13                      4.70  2015
# 14                      3.25  2015
# 15                      5.00  2015
# 16                      5.20  2015
# 17                      6.45  2015
# 18                      3.58  2015
# 19                      6.25  2015
# 20                      6.85  2015
# 21                      6.68  2015
# 22                      5.89  2015
# 23                      6.37  2015
# 24                      5.35  2015
# 25                      3.01  2015
# 26                      5.02  2015
# 27                      2.84  2015
# 28                      2.66  2015
# 29                      2.95  2015
# ..                       ...   ...
# 56                      3.96  2016
# 57                      3.04  2016
# 58                      3.57  2016
# 59                      4.02  2016
# 60                      4.39  2016
# 61                      4.96  2016
# 62                      4.91  2016
# 63                      5.30  2016
# 64                      5.14  2016
# 65                      4.83  2016
# 66                      4.70  2016
# 67                      4.57  2016
# 68                      3.01  2016
# 69                      4.03  2016
# 70                      3.57  2016
# 71                      2.95  2016
# 72                      2.44  2016
# 73                      2.15  2016
# 74                      1.07  2016
# 75                      1.64  2016
# 76                      1.28  2016
# 77                      1.02  2016
# 78                      0.79  2016
# 79                      0.72  2016
# 80                      0.63  2016
# 81                      0.67  2016
# 82                      0.55  2016
# 83                      0.63  2016
# 84                      0.65  2016
# 85                      0.63  2016
#
# [86 rows x 6 columns]

# %%
years2_total = years2_small[years2_small['Age'].str.contains('Total', na=False)]
years2_total
# Out:
#        Age  Fertility Rate (‰) 1st Births.rate  2nd Births.rate  \
# 0    Total               37.33            21.5             13.4
# 43   Total               30.93           16.43             12.3
#
#     3rd Births and over.rate  year
# 0                       2.41  2015
# 43                      2.21  2016

# %%
frames = [years_total , years2_total]
total_years = pd.concat(frames)
total_years
# Out:
#            Age  Fertility Rate (‰) 1st Births.rate  2nd Births.rate  \
# 304      Total               38.01           26.12            10.10
# 255      Total               38.29           26.53            10.44
# 51       Total               34.44           21.68            10.90
# 204      Total               34.99           23.02            10.62
# 448      Total               37.46           25.04            11.05
# 397      Total               38.83           26.22            11.18
# 347  总计  Total               36.14           24.24            10.60
# 102      Total               29.75           19.75             8.72
# 153      Total               35.89           23.38            10.92
# 0        Total               35.68           22.96            11.11
# 0        Total               37.33            21.5            13.40
# 43       Total               30.93           16.43            12.30
#
#      3rd Births and over.rate  year
# 304                      1.79  2004
# 255                      1.32  2005
# 51                       1.85  2006
# 204                      1.36  2007
# 448                      1.37  2008
# 397                      1.43  2009
# 347                      1.30  2010
# 102                      1.29  2012
# 153                      1.58  2013
# 0                        1.59  2014
# 0                        2.41  2015
# 43                       2.21  2016

# %%
total_years['Age'] = total_years['Age'].str.extract(r"\s(\w+)")

# %%
total_years
# Out:
#        Age  Fertility Rate (‰) 1st Births.rate  2nd Births.rate  \
# 304  Total               38.01           26.12            10.10
# 255    NaN               38.29           26.53            10.44
# 51   Total               34.44           21.68            10.90
# 204  Total               34.99           23.02            10.62
# 448    NaN               37.46           25.04            11.05
# 397    NaN               38.83           26.22            11.18
# 347  Total               36.14           24.24            10.60
# 102    NaN               29.75           19.75             8.72
# 153    NaN               35.89           23.38            10.92
# 0      NaN               35.68           22.96            11.11
# 0    Total               37.33            21.5            13.40
# 43   Total               30.93           16.43            12.30
#
#      3rd Births and over.rate  year
# 304                      1.79  2004
# 255                      1.32  2005
# 51                       1.85  2006
# 204                      1.36  2007
# 448                      1.37  2008
# 397                      1.43  2009
# 347                      1.30  2010
# 102                      1.29  2012
# 153                      1.58  2013
# 0                        1.59  2014
# 0                        2.41  2015
# 43                       2.21  2016

# %%
total_years = total_years.append({'Age': "Total", 'Fertility Rate (‰)': '0', '1st Births.rate': '0', '2nd Births.rate': '0', '3rd Births and over.rate':'0', 'year': '2011'},ignore_index=True)
total_years
# Out:
#       Age Fertility Rate (‰) 1st Births.rate 2nd Births.rate  \
# 0   Total              38.01           26.12            10.1
# 1     NaN              38.29           26.53           10.44
# 2   Total              34.44           21.68            10.9
# 3   Total              34.99           23.02           10.62
# 4     NaN              37.46           25.04           11.05
# 5     NaN              38.83           26.22           11.18
# 6   Total              36.14           24.24            10.6
# 7     NaN              29.75           19.75            8.72
# 8     NaN              35.89           23.38           10.92
# 9     NaN              35.68           22.96           11.11
# 10  Total              37.33            21.5            13.4
# 11  Total              30.93           16.43            12.3
# 12  Total                  0               0               0
#
#    3rd Births and over.rate  year
# 0                      1.79  2004
# 1                      1.32  2005
# 2                      1.85  2006
# 3                      1.36  2007
# 4                      1.37  2008
# 5                      1.43  2009
# 6                       1.3  2010
# 7                      1.29  2012
# 8                      1.58  2013
# 9                      1.59  2014
# 10                     2.41  2015
# 11                     2.21  2016
# 12                        0  2011

# %%
total_years['1st Births.rate'] = total_years['1st Births.rate'].astype(float)

# %%
total_years['2nd Births.rate'] = total_years['2nd Births.rate'].astype(float)

# %%
total_years['3rd Births and over.rate'] = total_years['3rd Births and over.rate'].astype(float)

# %%
total_years = total_years.sort_values(by='year', ascending = False)
total_years.dtypes
# Out:
# Age                          object
# Fertility Rate (‰)           object
# 1st Births.rate             float64
# 2nd Births.rate             float64
# 3rd Births and over.rate    float64
# year                         object
# dtype: object

# %%
total_years.plot(kind='barh', x ='year', y= ['1st Births.rate', '2nd Births.rate', '3rd Births and over.rate'], stacked =True, figsize=(10,6))
